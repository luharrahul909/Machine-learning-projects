# %% [markdown]
# <a href="https://colab.research.google.com/github/luharrahul909/Machine-learning-projects/blob/master/Basic_Face_detection_project_using_openCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
img = cv2.imread("rah.jpg",1)
print(img)
# Out:
# [[[192 201 221]
#   [191 202 222]
#   [192 203 223]
#   ...
#   [174 165 175]
#   [178 168 174]
#   [172 164 165]]
#
#  [[194 203 223]
#   [193 204 224]
#   [192 206 225]
#   ...
#   [170 161 171]
#   [172 165 170]
#   [168 162 163]]
#
#  [[196 207 227]
#   [194 208 227]
#   [195 209 228]
#   ...
#   [165 157 167]
#   [167 161 166]
#   [166 161 162]]
#
#  ...
#
#  [[217 187 170]
#   [219 189 172]
#   [222 192 175]
#   ...
#   [ 94 110 117]
#   [ 92 109 118]
#   [ 93 110 119]]
#
#  [[213 181 162]
#   [215 183 164]
#   [214 184 165]
#   ...
#   [ 84 109 113]
#   [ 81 107 113]
#   [ 80 109 114]]
#
#  [[216 185 164]
#   [218 187 166]
#   [217 187 168]
#   ...
#   [ 78 109 110]
#   [ 78 108 113]
#   [ 76 108 113]]]

# %%
print(img.shape)
# Out:
# (720, 1280, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FBF04E9B080>

# %% [markdown]
# # New Section

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

gray_img = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray_img, 1.05, 5)

print(type(faces))
print(faces)

for x,y,w,h in faces:

    img = cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 3 )

    resized = cv2.resize(img, (int (img.shape[1]), int (img.shape[0]) ) )
    cv2_imshow(resized)
    cv2.waitKey(0)
# Out:
# <class 'numpy.ndarray'>
# [[531 121 372 372]
#  [604 274 237 237]]
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FBF04E98CF8>
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FBF04E98358>

# %%
import cv2,time

video = cv2.VideoCapture(0)

check,frame = video.read()

print(check)
print(frame)

time.sleep(3)

cv2_imshow(frame)
cv2.waitKey(0)

video.release()

cv2.destroyAllWindows()
# Out:
# False
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-2cef89c2f4c2> in <module>()
#      10 time.sleep(3)
#      11
# ---> 12 cv2_imshow(frame)
#      13 cv2.waitKey(0)
#      14
#
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
