# %% [markdown]
# <a href="https://colab.research.google.com/github/luharrahul909/Machine-learning-projects/blob/master/Basic_Face_detection_project_using_openCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
img = cv2.imread("Luh.jpg",1)
print(img)
# Out:
# [[[184 170 117]
#   [192 180 126]
#   [186 176 122]
#   ...
#   [156 143 167]
#   [165 152 176]
#   [166 153 177]]
#
#  [[189 175 122]
#   [183 171 117]
#   [189 182 127]
#   ...
#   [149 139 162]
#   [158 148 171]
#   [167 157 180]]
#
#  [[189 178 121]
#   [189 180 123]
#   [184 177 120]
#   ...
#   [161 153 176]
#   [162 154 177]
#   [158 150 173]]
#
#  ...
#
#  [[231 233 221]
#   [240 242 230]
#   [245 248 233]
#   ...
#   [ 94 115 117]
#   [ 95 114 117]
#   [ 91 112 114]]
#
#  [[235 236 226]
#   [239 241 229]
#   [241 244 229]
#   ...
#   [ 65  93  94]
#   [ 54  79  81]
#   [ 42  70  71]]
#
#  [[243 244 234]
#   [237 239 227]
#   [236 238 226]
#   ...
#   [ 70 100 101]
#   [ 80 110 111]
#   [ 99 129 130]]]

# %%
print(img.shape)
# Out:
# (720, 1280, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F13CFF20DA0>

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

gray_img = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray_img, 1.05, 5)

print(type(faces))
print(faces)

for x,y,w,h in faces:

    img = cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 3 )

    resized = cv2.resize(img, (int (img.shape[1]), int (img.shape[0]) ) )
    cv2_imshow(resized)
    cv2.waitKey(0)
# Out:
# <class 'numpy.ndarray'>
# [[536 319 233 233]]
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F13CFF2D898>
